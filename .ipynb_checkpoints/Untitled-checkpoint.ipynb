# %%
import pandas as pd

# %%
scores = [20, 65, 80, 95, 45, 22]

# %%
scores = pd.Series(scores)
scores
# Out:
# 0    20
# 1    65
# 2    80
# 3    95
# 4    45
# 5    22
# dtype: int64

# %%
scores[1:4]
# Out:
# 1    65
# 2    80
# 3    95
# dtype: int64

# %%
scores.iloc[1:4]
# Out:
# 1    65
# 2    80
# 3    95
# dtype: int64

# %%
scores[scores > 50]
# Out:
# 1    65
# 2    80
# 3    95
# dtype: int64
