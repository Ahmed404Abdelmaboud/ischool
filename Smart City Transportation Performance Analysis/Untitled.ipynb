# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =  pd.read_csv("data/Cleaned_Data.csv")
data.head()
# Out:
#    Unnamed: 0 Route_ID Transport_Type    Station  Passengers  Delay_Minutes  \
# 0           0     R101            Bus    Central       120.0           15.0
# 1           1     R102          Metro   Downtown       300.0            2.0
# 2           2     R103            Bus    Central       110.0           20.0
# 3           3     R104           Tram  Riverside        80.0            5.0
# 4           5     R105          Metro   Downtown       280.0            5.0
#
#    Trip_Duration Day_Type
# 0             40  Weekday
# 1             25  Weekday
# 2             45  Weekday
# 3             30  Weekend
# 4             24  Weekday

# %%
data.describe()
# Out:
#        Unnamed: 0  Passengers  Delay_Minutes  Trip_Duration
# count    9.000000    9.000000       9.000000       9.000000
# mean     4.555556  168.333333      10.555556      33.777778
# std      3.205897  108.742816       8.959787      10.639288
# min      0.000000   75.000000       1.000000      20.000000
# 25%      2.000000   90.000000       4.000000      25.000000
# 50%      5.000000  110.000000       5.000000      30.000000
# 75%      7.000000  280.000000      18.000000      42.000000
# max      9.000000  350.000000      25.000000      50.000000

# %%
traffic = data.groupby("Station")["Delay_Minutes"].sum().sort_values(ascending = False).reset_index()
traffic
# Out:
#      Station  Delay_Minutes
# 0    Central           36.0
# 1    Airport           25.0
# 2     Uptown           18.0
# 3  Riverside            9.0
# 4   Downtown            7.0

# %%
bars = sns.barplot(data = traffic, x = "Station", y = "Delay_Minutes")
for bar in bars.patches:
    height = bar.get_height()
    plt.annotate(f"{height}", xy = (bar.get_x() + bar.get_width() / 2, height + 1000), ha = "center");

# %%
transport = data["Transport_Type"].value_counts().reset_index()
transport
# Out:
#   Transport_Type  count
# 0            Bus      4
# 1          Metro      3
# 2           Tram      2

# %%
plt.pie(transport["count"] / transport["count"].sum() * 100, labels = transport["Transport_Type"], autopct = "%1.1f%%");

# %%
data["Delay_Minutes"].sort_values(ascending = False)
# Out:
# 5    25.0
# 2    20.0
# 8    18.0
# 0    15.0
# 3     5.0
# 4     5.0
# 6     4.0
# 1     2.0
# 7     1.0
# Name: Delay_Minutes, dtype: float64

# %%
sns.histplot(data["Delay_Minutes"]);
