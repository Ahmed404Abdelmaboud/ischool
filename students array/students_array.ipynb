# %%
import numpy as np

# %%
students = np.array([
    ("Ahmed", 16, 92.5),
    ("Sara", 15, 88.0),
    ("Mahmoud", 17, 95.3),
    ("Laila", 16, 90.2)
], dtype=[("name", "U20"), ("age", "i4"), ("grade", "f4")])

# %%
students["name"]
# Out:
# array(['Ahmed', 'Sara', 'Mahmoud', 'Laila'], dtype='<U20')

# %%
students["age"]
# Out:
# array([16, 15, 17, 16], dtype=int32)

# %%
students["grade"]
# Out:
# array([92.5, 88. , 95.3, 90.2], dtype=float32)

# %%
students[students["name"] == "Ahmed"]["age"]
# Out:
# array([16], dtype=int32)
